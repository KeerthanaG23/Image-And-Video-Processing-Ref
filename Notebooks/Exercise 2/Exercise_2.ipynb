# %% [markdown]
# https://vincmazet.github.io/bip/interpolation/interpolation.html

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread(r"E:\Image processing\Lab\Exercise 2\Flag.png")

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
h,w,c = image.shape

# %%
h
# Out:
# 163

# %%
w
# Out:
# 310

# %%
c
# Out:
# 3

# %%
plt.imshow(image)

# %% [markdown]
# ### NEAREST NEIGHBOUR INTERPOLATION

# %%
new_image_1 = cv2.resize(image, (w//9, h//9), interpolation = cv2.INTER_NEAREST)
plt.imshow(new_image_1)
new_image_2 = cv2.resize(image, (w, h//9), interpolation = cv2.INTER_NEAREST)
plt.imshow(new_image_2)
new_image_3 = cv2.resize(image, (w//9, h), interpolation = cv2.INTER_NEAREST)

plt.imshow(new_image_3)

new_image_4 = cv2.resize(image, (w//9, h//9), interpolation = cv2.INTER_AREA)
plt.imshow(new_image_4)

new_image_5 = cv2.resize(image, (w//9, h//9), interpolation = cv2.INTER_BITS)
plt.imshow(new_image_5)

new_image_6 = cv2.resize(image, (w//9, h//9), interpolation = cv2.INTER_BITS2)
plt.imshow(new_image_6)

new_image_7 = cv2.resize(image, (w//9, h//9), interpolation = cv2.INTER_LANCZOS4)
plt.imshow(new_image_7)

new_image_8 = cv2.resize(image, (w//9, h//9), interpolation = cv2.INTER_LINEAR_EXACT)
plt.imshow(new_image_8)

new_image_9 = cv2.resize(image, (w//9, h//9), interpolation = cv2.INTER_NEAREST_EXACT)
plt.imshow(new_image_9)

# %%
new_image = cv2.resize(image, (w//9, h), interpolation = cv2.INTER_NEAREST)

# %%
plt.imshow(new_image)

# %%
new_image = cv2.resize(image, (w//9, h//9), interpolation = cv2.INTER_AREA)
plt.imshow(new_image)

# %%
new_image = cv2.resize(image, (w//9, h//9), interpolation = cv2.INTER_BITS)
plt.imshow(new_image)

# %%
new_image = cv2.resize(image, (w//9, h//9), interpolation = cv2.INTER_BITS2)
plt.imshow(new_image)

# %%
new_image = cv2.resize(image, (w//9, h//9), interpolation = cv2.INTER_LANCZOS4)
plt.imshow(new_image)

# %%
new_image = cv2.resize(image, (w//9, h//9), interpolation = cv2.INTER_LINEAR_EXACT)
plt.imshow(new_image)

# %%
new_image = cv2.resize(image, (w//9, h//9), interpolation = cv2.INTER_NEAREST_EXACT)
plt.imshow(new_image)

# %% [markdown]
# https://annmay10.medium.com/resizing-images-using-various-interpolation-techniques-4b99800999f2

# %%
import cv2

original_image=image
# Display the original image
cv2.imshow('Original Image', original_image)
# Convert to Grayscale and display
grayscale_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Grayscale Image', grayscale_image)

# Convert to RGB and display
rgb_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
cv2.imshow('RGB Image', rgb_image)


# Convert to HSV and display
hsv_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2HSV)
cv2.imshow('HSV Image', hsv_image)
# Out:
# True

# %%
plt.imshow( grayscale_image)
plt.savefig('output.jpg')

# %%
plt.imshow(rgb_image)

# %%
plt.imshow(hsv_image)

# %%
import cv2
import matplotlib.pyplot as plt


# Split the image into its RGB color channels
b, g, r = cv2.split(image)

# Display the original and individual color channels
plt.figure(figsize=(10, 4))

plt.subplot(141)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(142)
plt.imshow(b, cmap='gray')
plt.title('Blue Channel')

plt.subplot(143)
plt.imshow(g, cmap='gray')
plt.title('Green Channel')

plt.subplot(144)
plt.imshow(r, cmap='gray')
plt.title('Red Channel')

plt.show()

# %%
import cv2
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Convert the image from BGR to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Reshape the image to a 2D array of pixels
pixels = image_rgb.reshape((-1, 3))

# Perform k-means clustering
num_clusters = 5  # You can adjust this value based on your requirement
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(pixels)

# Get the cluster centers and labels
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# Assign each pixel to its corresponding cluster center
segmented_image = centers[labels].reshape(image_rgb.shape)

# Display the original image and the segmented image
plt.figure(figsize=(10, 5))

plt.subplot(121)
plt.imshow(image_rgb)
plt.title('Original Image')

plt.subplot(122)
plt.imshow(segmented_image.astype(np.uint8))
plt.title('Segmented Image (K-Means Clustering)')

plt.show()

# Display the unique colors in a separate plot
plt.figure(figsize=(8, 2))
plt.imshow([centers.astype(np.uint8)])
plt.title('Unique Colors (Cluster Centers)')
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Read the input image

# Display the original image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.show()

# Save the image in different formats

# Convert to JPEG
cv2.imwrite('output_image.jpg', image)

# Convert to PNG
cv2.imwrite('output_image.png', image)

# Convert to TIFF
cv2.imwrite('output_image.tiff', image)

# Display the saved images (optional)
jpeg_image = cv2.imread('output_image.jpg')
png_image = cv2.imread('output_image.png')
tiff_image = cv2.imread('output_image.tiff')

plt.figure(figsize=(15, 5))

plt.subplot(131)
plt.imshow(cv2.cvtColor(jpeg_image, cv2.COLOR_BGR2RGB))
plt.title('JPEG Format')

plt.subplot(132)
plt.imshow(cv2.cvtColor(png_image, cv2.COLOR_BGR2RGB))
plt.title('PNG Format')

plt.subplot(133)
plt.imshow(cv2.cvtColor(tiff_image, cv2.COLOR_BGR2RGB))
plt.title('TIFF Format')

plt.show()
